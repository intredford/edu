# %%
import matplotlib.pyplot as plt

#@markdown #**Тест "подходящий вид досуга"**
#@markdown 1. Будучи школьником, какие предметы интересовали вас больше всего?
first = "3. \u0422\u0440\u0443\u0434\u044B." #@param ["1. \u0424\u0438\u0437\u0438\u0447\u0435\u0441\u043A\u0430\u044F \u043A\u0443\u043B\u044C\u0442\u0443\u0440\u0430.", "2. \u041C\u0443\u0437\u044B\u043A\u0430, \u0418\u0417\u041E, \u043B\u0438\u0442\u0435\u0440\u0430\u0442\u0443\u0440\u0430.", "3. \u0422\u0440\u0443\u0434\u044B.", "4. \u0413\u0435\u043E\u043C\u0435\u0442\u0440\u0438\u044F, \u0430\u043B\u0433\u0435\u0431\u0440\u0430, \u0445\u0438\u043C\u0438\u044F, \u0444\u0438\u0437\u0438\u043A\u0430.", "5. \u0411\u0438\u043E\u043B\u043E\u0433\u0438\u044F, \u0431\u043E\u0442\u0430\u043D\u0438\u043A\u0430, \u0433\u0435\u043E\u0433\u0440\u0430\u0444\u0438\u044F, \u043F\u0440\u0438\u0440\u043E\u0434\u043E\u0432\u0435\u0434\u0435\u043D\u0438\u0435."]
#@markdown 2. По телевизору показывают клип любимого певца. В это время вы:
second = "5. \u041F\u0440\u0435\u0434\u0441\u0442\u0430\u0432\u043B\u044F\u0435\u0442\u0435 \u0441\u0435\u0431\u044F \u0432 \u044D\u0442\u043E\u043C \u043A\u043B\u0438\u043F\u0435." #@param ["1. Начинаете танцевать либо подпевать.", "2. Представляете, какую визуальную картинку «смастерили» бы, будучи режиссером клипа.", "3. Изучаете внешний вид исполнителя – костюм, макияж, прическу.", "4. Анализируете, совпадает ли сюжет клипа и поведение певца со смыслом песни.", "5. Представляете себя в этом клипе."]
#@markdown 3. Закончился очередной рабочий день. Что вы будете делать, вернувшись домой?
third = "1. \u0417\u0430\u0440\u044F\u0434\u043A\u0430-\u043F\u044F\u0442\u0438\u043C\u0438\u043D\u0443\u0442\u043A\u0430 \u043D\u0435 \u043F\u043E\u0432\u0440\u0435\u0434\u0438\u0442!" #@param ["1. \u0417\u0430\u0440\u044F\u0434\u043A\u0430-\u043F\u044F\u0442\u0438\u043C\u0438\u043D\u0443\u0442\u043A\u0430 \u043D\u0435 \u043F\u043E\u0432\u0440\u0435\u0434\u0438\u0442!", "2. \u0412\u043E\u0437\u044C\u043C\u0435\u0442\u0435 \u0432 \u0440\u0443\u043A\u0438 \u0438\u043D\u0442\u0435\u0440\u0435\u0441\u043D\u0443\u044E \u043A\u043D\u0438\u0433\u0443.", "3. \u0417\u0430\u0441\u044F\u0434\u0435\u0442\u0435 \u0437\u0430 \u0432\u044B\u0448\u0438\u0432\u043A\u043E\u0439/\u0432\u044F\u0437\u0430\u043D\u0438\u0435\u043C/\u0438\u043A\u0435\u0431
#@markdown 5. Идеальный отдых?
fifth = "5. \u041F\u043E\u0445\u043E\u0434 \u0432 \u0433\u043E\u0440\u044B \u0438\u043B\u0438 \u043F\u0440\u044B\u0436\u043E\u043A \u0441 \u043F\u0430\u0440\u0430\u0448\u044E\u0442\u043E\u043C." #@param ["1. \u041A\u0430\u0442\u0430\u043D\u0438\u0435 \u043F\u043E \u0433\u043E\u0440\u043E\u0434\u0443 \u043D\u0430 \u0432\u0435\u043B\u043E\u0441\u0438\u043F\u0435\u0434\u0430\u0445 \u0438\u043B\u0438 \u0440\u043E\u043B\u0438\u043A\u0430\u0445.", "2. \u041F\u043E\u0445\u043E\u0434 \u0432 \u043C\u0443\u0437\u0435\u0439, \u0442\u0435\u0430\u0442\u0440 \u0438\u043B\u0438 \u043D\u0430 \u043A\u043E\u043D\u0446\u0435\u0440\u0442.", "3. \u0421\u0445\u043E\u0436\u0443 \u0432 \u043A\u0430\u0444\u0435, \u043F\u043E\u0433\u0443\u043B\u044F\u044E \u043F\u0440\u043E\u0439\u0434\u0443\u0441\u044C \u043F\u043E \u043C\u0430\u0433\u0430\u0437\u0438\u043D\u0430\u043C.", "4. \u0414\u043E\u043C\u0430 - \u043F\u043E\u0447\u0438\u0442\u0430\u044E \u043A\u043D\u0438\u0433\u0443, \u043F\u043E\u0441\u043C\u043E\u0442\u0440\u044E \u0444\u0438\u043B\u044C\u043C.", "5. \u041F\u043E\u0445\u043E\u0434 \u0432 \u0433\u043E\u0440\u044B \u0438\u043B\u0438 \u043F\u0440\u044B\u0436\u043E\u043A \u0441 \u043F\u0430\u0440\u0430\u0448\u044E\u0442\u043E\u043C."]
variable_name = ""

answers = [first, second, third, fourth, fifth]

skills = [
    {
        'value': 0,
        'name': 'Спорт'
    },
    {
        'value': 0,
        'name': 'Творчество'
    },
    {
        'value': 0,
        'name': 'Рукоделие'
    },
    {
        'value': 0,
        'name': 'Интеллект'
    },
    {
        'value': 0,
        'name': 'Приключения'
    },
]

for answer in answers:
  skills[int(answer[0])-1]['value'] += 1

for skill in skills:
  print('{}: {}.\n'.format(skill['name'], skill['value']))

labels = [skill['name'] for skill in skills]
sections = [skill['value'] for skill in skills]
colors = ['yellowgreen', 'lightgreen', 'darkgreen', 'gold', 'red',]

plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        autopct='%.2f%%',
        shadow=True,
        explode=None
        )

plt.title('Диаграмма результата')
plt.show()
# Out:
# Спорт: 1.
#
# Творчество: 0.
#
# Рукоделие: 1.
#
# Интеллект: 1.
#
# Приключения: 2.
